# %% [markdown]
# # nb1 — Phase 0 (tiếp): Align âm tiết → pseudo-annotation cho bộ test 6k
#
# Notebook thứ hai trong chuỗi nb0→nb3 (DESIGN.md §7): nhận output của nb0, xây **module align âm tiết** (Levenshtein trên chuỗi token canonical), kiểm thử trên case biên đã biết, **kiểm chứng trên gold annotation của toàn bộ VSEC** (3 tầng), align bộ test 6k → pseudo-annotation schema giống VSEC, thống kê câu sạch (trả lời câu hỏi treo DESIGN.md §11.1) và QA 50 mẫu để soát tay.
#
# Tham chiếu: `PROJECT.md` §3.2 (edge case annotation) · `DESIGN.md` §2 (module align + QA alignment), §6 (align là chỗ dễ sai nhất — phải kiểm thử kỹ), §9 (checklist leakage).
#
# **Input**: output nb0 — trên Kaggle: *Add Input* dataset tạo từ nb0 (file nằm trong `/kaggle/input/<tên-dataset>/`); local: `./out`. **Không cần Internet**, không cài package mới (chỉ stdlib — mọi trường VSEC cần thiết đã có trong jsonl của nb0).
#
# **Nguyên tắc leakage (DESIGN.md §9)**: align trên test chỉ phục vụ **đánh giá** (tạo pseudo-gold), không fit tham số/thống kê nào của model. Kiểm chứng trên gold VSEC là tool-validation — không liên quan training.
#
# ## Nội dung
# 0. Cấu hình + tự dò input nb0
# 1. Cell hàm dùng chung — có `SHARED_CELLS_VERSION` để đối chiếu với nb3
# 2. Assert các case biên (split/merge/insert/delete/hoa-thường/dấu câu)
# 3. Kiểm chứng aligner trên gold VSEC — 3 tầng
# 4. Align test 6k
# 5. Roundtrip invariant (VSEC + test) — assert 100%
# 6. Thống kê (câu sạch, loại edit, suspect)
# 7. QA 50 mẫu in ra soát tay
# 8. Xuất `test_aligned.jsonl` + `qa_samples.json` + `align_report.json`

# %% [markdown]
# ## 0. Cấu hình — mọi tham số gom một chỗ (DESIGN.md §7)
#
# | Tham số | Giá trị | Ý nghĩa |
# |---|---|---|
# | `SEED` | `42` | seed cho chọn mẫu QA (tái lập được) |
# | `QA_N` | `50` | số mẫu QA in ra soát tay (DESIGN.md §2: ~50) |
# | `SUSPECT_EDIT_RATIO` | `0.3` | ngưỡng đánh dấu câu *suspect*: edit quá dày so với độ dài câu → pseudo-annotation khó tin, thống kê riêng |
#
# **Input tự dò**: quét `/kaggle/input/**/manifest.json` (Kaggle) rồi `./out/manifest.json` (local) — lấy thư mục đầu tiên có đủ `manifest.json` + `vsec_train.jsonl` + `vsec_val.jsonl` + `test_normalized.jsonl`. **Thiếu file → dừng sớm** với hướng dẫn sửa (nb0 phải chạy khi CÓ bộ test 6k thì mới sinh ra `test_normalized.jsonl` — nb0 §6).

# %%
import datetime
import json
from pathlib import Path

SEED = 42
QA_N = 50
SUSPECT_EDIT_RATIO = 0.3

REQUIRED_FILES = ['manifest.json', 'vsec_train.jsonl', 'vsec_val.jsonl', 'test_normalized.jsonl']


def find_nb0_output():
    """Tự dò thư mục output của nb0: /kaggle/input/**/manifest.json rồi ./out/manifest.json."""
    candidates = []
    kaggle = Path('/kaggle/input')
    if kaggle.is_dir():
        candidates += sorted(kaggle.rglob('manifest.json'))
    local = Path('./out/manifest.json')
    if local.is_file():
        candidates.append(local)
    for m in candidates:
        if all((m.parent / f).is_file() for f in REQUIRED_FILES):
            return m.parent
    return None


INPUT_DIR = find_nb0_output()
if INPUT_DIR is None:
    raise FileNotFoundError(
        'Không tìm thấy output của nb0 (cần đủ: ' + ', '.join(REQUIRED_FILES) + '). '
        'Trên Kaggle: Add Input dataset đã tạo từ nb0 (xem nb0 §9). Local: chạy nb0 với OUTPUT_DIR ./out. '
        'Lưu ý: nb0 phải chạy khi CÓ bộ test 6k thì output mới có test_normalized.jsonl (nb0 §6).'
    )

OUTPUT_DIR = Path('/kaggle/working') if Path('/kaggle/working').is_dir() else Path('./out')
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
RUN_STAMP = datetime.datetime.now().isoformat(timespec='seconds')
manifest_nb0 = json.loads((INPUT_DIR / 'manifest.json').read_text(encoding='utf-8'))

print('INPUT_DIR :', INPUT_DIR)
print('OUTPUT_DIR:', OUTPUT_DIR)
print('nb0 manifest:', manifest_nb0.get('notebook'), '— tạo', manifest_nb0.get('created'))
print(f'SEED={SEED}  QA_N={QA_N}  SUSPECT_EDIT_RATIO={SUSPECT_EDIT_RATIO}')
print('Số câu theo manifest nb0 — VSEC sau dedupe:', manifest_nb0.get('vsec', {}).get('after_dedupe'),
      '· test sau dedupe:', manifest_nb0.get('test', {}).get('after_dedupe'))
# Out:
# INPUT_DIR : /kaggle/input/notebooks/cquangnguynl/nb0-data-pre
# OUTPUT_DIR: /kaggle/working
# nb0 manifest: nb0_data_prep — tạo 2026-09-22T07:16:53
# SEED=42  QA_N=50  SUSPECT_EDIT_RATIO=0.3
# Số câu theo manifest nb0 — VSEC sau dedupe: 9270 · test sau dedupe: 5983

# %% [markdown]
# ## 1. Cell hàm dùng chung — copy NGUYÊN VẸT sang nb3 (DESIGN.md §7)
#
# nb3 sẽ copy cell này y hệt (không sửa) để (a) align `source ↔ model output` khi eval và (b) tự tính lại pseudo-annotation cho VSEC-val (quyết định 22/09: nb1 **không xuất** `vsec_*_aligned.jsonl`). Hằng số `SHARED_CELLS_VERSION` in ra khi chạy — nếu nb3 in khác version nghĩa là 2 notebook đã lệch nhau; lúc đó phải đồng bộ lại hoặc trích `.py` chung (nguyên tắc DESIGN.md §7: sửa ở ≥2 nơi thì trích module).
#
# Hàm chính:
#
# - `nfc_normalize(s)` — copy y hệt từ nb0 (NFC + strip + gộp khoảng trắng).
# - `canon_tokenize(s)` — **token canonical**: NFC rồi tách bằng `re.findall(r'\w+|[^\w\s]+')` — run chữ/số liên liền là 1 token, cụm dấu câu liền kề là 1 token riêng. Đây là cách chuẩn hóa "dấu câu tách space như VSEC" (DESIGN.md §2.4) áp dụng **thống nhất cho VSEC / test / output model**, đưa cả 3 về cùng một hệ tọa độ. So sánh token **case-sensitive** (`tronG` ≠ `trong` — lỗi hoa/thường là lỗi thật trong bộ test).
# - `levenshtein_opcodes(src, tgt)` — DP thuần Python (sub/ins/del = 1) có backtrace, trả opcodes kiểu difflib. Không thêm dependency.
# - `extract_edit_blocks(...)` — gộp các opcode không-`equal` **liền kề** thành 1 edit block → chịu được split/merge/dịch vị trí (chỗ dễ sai nhất theo DESIGN.md §6).
# - `build_pseudo_annotation(text, corrected)` — dựng annotation schema giống VSEC.
# - `apply_edit_blocks(src, blocks)` — dùng cho roundtrip invariant (§5).
#
# Loại block (theo số token nguồn → đích); `position` luôn là **index trong hệ token canonical**:
#
# | type | nguồn → đích | ví dụ |
# |---|---|---|
# | `substitute` | 1 → 1 | `sanh` → `xanh` |
# | `split` | 1 → n | `vàahệ` → `và hệ` (từ dính, sửa tách ra) |
# | `merge` | m → 1 | `nh iên` → `nhiên` (âm tiết bị tách sai, sửa dính lại) |
# | `insert` | 0 → n | nguồn thiếu âm tiết: `đi học` → `đi rồi học` |
# | `delete` | m → 0 | nguồn thừa âm tiết: `Anh rồi đi` → `Anh đi` |
# | `multi` | m → n | cụm phức tạp / lỗi kề nhau gộp block |
#
# Quy ước quan trọng (chi tiết trong docstring `build_pseudo_annotation`):
#
# - **`error_positions`** chỉ chứa vị trí token nguồn của block **có** token nguồn. Block `insert` không có vị trí nguồn → chỉ nằm trong `correction_pairs` với `error = ''`, `position` = vị trí chèn trước (có thể == `len(src)`), và **không** làm token nguồn nào thành `is_correct = False`.
# - **`punct_only`**: block mà cả 2 vế chỉ toàn dấu câu → giữ lại kèm flag, để lọc/báo cáo riêng ở nb3.
# - **`suspect`**: `edit_ratio` (tổng token nằm trong edit, tính cả 2 vế, chia `max(len(src), len(tgt))`) vượt `SUSPECT_EDIT_RATIO` → chỉ đánh dấu, không loại.
# - Eval ở nb3 so khớp theo **block-overlap** (block model chồng lấn block gold theo span), không so index tuyệt đối — chịu được split/merge/dịch vị trí.

# %%
import re
import unicodedata

SHARED_CELLS_VERSION = 'align-v1'

_WS_RE = re.compile(r'\s+')
_TOKEN_RE = re.compile(r'\w+|[^\w\s]+')
_HAS_WORD_RE = re.compile(r'\w')


def nfc_normalize(s):
    return _WS_RE.sub(' ', unicodedata.normalize('NFC', s)).strip()


def canon_tokenize(s):
    """NFC + tách token: run chữ/số liên liền (\\w+) là 1 token; cụm dấu câu liền kề là 1 token riêng.
    Chuẩn hóa "style VSEC" (dấu câu tách space) triệt để — dùng THỐNG NHẤT cho VSEC / test / output
    model (DESIGN.md §2.4). So sánh token là case-sensitive ("tronG" ≠ "trong")."""
    return _TOKEN_RE.findall(nfc_normalize(s))


def is_punct_token(tok):
    return not _HAS_WORD_RE.search(tok)


def levenshtein_opcodes(src, tgt):
    """Levenshtein DP thuần Python (sub/ins/del = 1) trên 2 chuỗi token.
    Trả về opcodes kiểu difflib: list (tag, i1, i2, j1, j2) với tag ∈ {equal, replace, insert, delete},
    phủ kín src[i1:i2] ↔ tgt[j1:j2], không chồng lấn, theo thứ tự xuất hiện."""
    n, m = len(src), len(tgt)
    dp = [[0] * (m + 1) for _ in range(n + 1)]
    for i in range(1, n + 1):
        dp[i][0] = i
    for j in range(1, m + 1):
        dp[0][j] = j
    for i in range(1, n + 1):
        si = src[i - 1]
        prev, row = dp[i - 1], dp[i]
        for j in range(1, m + 1):
            best = prev[j - 1] + (0 if si == tgt[j - 1] else 1)  # match / substitute
            if prev[j] + 1 < best:  # delete token nguồn
                best = prev[j] + 1
            if row[j - 1] + 1 < best:  # insert token đích
                best = row[j - 1] + 1
            row[j] = best
    ops = []

    def _push(tag, i1, i2, j1, j2):
        if ops and ops[-1][0] == tag and ops[-1][1] == i2 and ops[-1][3] == j2:
            ops[-1] = (tag, i1, ops[-1][2], j1, ops[-1][4])
        else:
            ops.append((tag, i1, i2, j1, j2))

    i, j = n, m
    while i > 0 or j > 0:
        if i > 0 and j > 0 and dp[i][j] == dp[i - 1][j - 1] + (0 if src[i - 1] == tgt[j - 1] else 1):
            _push('equal' if src[i - 1] == tgt[j - 1] else 'replace', i - 1, i, j - 1, j)
            i, j = i - 1, j - 1
        elif i > 0 and dp[i][j] == dp[i - 1][j] + 1:
            _push('delete', i - 1, i, j, j)
            i -= 1
        else:
            _push('insert', i, i, j - 1, j)
            j -= 1
    ops.reverse()
    return ops


def _make_block(src, tgt, span):
    i1, i2, j1, j2 = span
    src_toks, tgt_toks = src[i1:i2], tgt[j1:j2]
    ns, nt = len(src_toks), len(tgt_toks)
    if ns == 0:
        btype = 'insert'
    elif nt == 0:
        btype = 'delete'
    elif ns == 1 and nt == 1:
        btype = 'substitute'
    elif ns == 1:
        btype = 'split'
    elif nt == 1:
        btype = 'merge'
    else:
        btype = 'multi'
    return {
        'type': btype,
        'position': i1,
        'src_span': [i1, i2],
        'tgt_span': [j1, j2],
        'src_tokens': src_toks,
        'tgt_tokens': tgt_toks,
        'punct_only': all(is_punct_token(t) for t in src_toks + tgt_toks),
    }


def extract_edit_blocks(src, tgt, opcodes):
    """Gộp các opcode không-equal liền kề thành 1 edit block (chịu được split/merge/dịch vị trí).
    type theo số token (nguồn → đích): substitute 1-1 · split 1→n · merge m→1 · insert 0→n ·
    delete m→0 · multi m→n. position = index token nguồn đầu tiên của block
    (insert: vị trí chèn trước, có thể == len(src))."""
    blocks, cur = [], None
    for tag, i1, i2, j1, j2 in opcodes:
        if tag == 'equal':
            if cur is not None:
                blocks.append(_make_block(src, tgt, cur))
                cur = None
        elif cur is None:
            cur = [i1, i2, j1, j2]
        else:
            cur[1], cur[3] = i2, j2
    if cur is not None:
        blocks.append(_make_block(src, tgt, cur))
    return blocks


def build_pseudo_annotation(text, corrected, suspect_ratio=SUSPECT_EDIT_RATIO):
    """Align text ↔ corrected_text trong hệ token canonical → pseudo-annotation schema giống VSEC + edit_blocks.
    Quy ước QUAN TRỌNG (nb3 phải dùng cell này nguyên vẹn):
    - error_positions: index token nguồn nằm trong src_span của block CÓ token nguồn.
      Block insert (thiếu âm tiết ở nguồn) KHÔNG có vị trí nguồn → không nằm trong error_positions,
      chỉ nằm trong correction_pairs với error='' và position = vị trí chèn trước (có thể == len(src)).
    - correction_pairs: 1 entry/block; error/correction = các token nối bằng space; delete → correction=''.
    - syllable_annotations: 1 entry/token nguồn; is_correct=False khi token thuộc src_span của block
      non-insert; corrections = chuỗi đích (join space) của block đó.
    - suspect: edit_ratio = (tổng token cả 2 vế nằm trong edit block) / max(len(src), len(tgt)) vượt ngưỡng.
    - align_failed: một trong hai vế token hóa rỗng."""
    src = canon_tokenize(text)
    tgt = canon_tokenize(corrected)
    blocks = extract_edit_blocks(src, tgt, levenshtein_opcodes(src, tgt))
    corrections_by_pos = {}
    for b in blocks:
        if b['src_span'][0] < b['src_span'][1]:
            fix = ' '.join(b['tgt_tokens'])
            for i in range(b['src_span'][0], b['src_span'][1]):
                corrections_by_pos.setdefault(i, []).append(fix)
    error_positions = sorted(corrections_by_pos)
    syllable_annotations = [
        {
            'syllable': tok,
            'is_correct': i not in corrections_by_pos,
            'corrections': corrections_by_pos.get(i, []),
            'position': i,
        }
        for i, tok in enumerate(src)
    ]
    correction_pairs = [
        {'error': ' '.join(b['src_tokens']), 'correction': ' '.join(b['tgt_tokens']), 'position': b['position']}
        for b in blocks
    ]
    n_edit_tokens = sum(
        (b['src_span'][1] - b['src_span'][0]) + (b['tgt_span'][1] - b['tgt_span'][0]) for b in blocks
    )
    denom = max(len(src), len(tgt))
    edit_ratio = n_edit_tokens / denom if denom else 0.0
    return {
        'is_clean': not blocks,
        'align_failed': not src or not tgt,
        'suspect': edit_ratio > suspect_ratio,
        'edit_ratio': round(edit_ratio, 4),
        'error_count': len(blocks),
        'error_positions': error_positions,
        'correction_pairs': correction_pairs,
        'syllable_annotations': syllable_annotations,
        'edit_blocks': blocks,
        'src_tokens': src,
        'tgt_tokens': tgt,
    }


def apply_edit_blocks(src, blocks):
    """Roundtrip invariant: áp edit blocks vào src tokens → phải thu về đúng tgt tokens."""
    out, pos = [], 0
    for b in blocks:
        out += src[pos:b['src_span'][0]]
        out += b['tgt_tokens']
        pos = b['src_span'][1]
    out += src[pos:]
    return out


print('SHARED_CELLS_VERSION:', SHARED_CELLS_VERSION)
# Out:
# SHARED_CELLS_VERSION: align-v1

# %% [markdown]
# ## 2. Kiểm thử case biên — assert
#
# Các case từ PROJECT.md §3.2 + đặc điểm bộ test (nhìn từ `data/6000.csv`): âm tiết tách sai, từ dính, ký tự thừa đầu từ, câu sạch, lỗi hoa/thường (`tronG`), thiếu/thừa âm tiết, khác chỉ dấu câu. Mỗi case đồng thời assert **roundtrip** (`src + edit_blocks == tgt`).

# %%
def _ann(text, corrected):
    a = build_pseudo_annotation(text, corrected)
    assert apply_edit_blocks(a['src_tokens'], a['edit_blocks']) == a['tgt_tokens'], (text, corrected)
    return a


# 1. Âm tiết tách sai: 2 token nguồn → 1 token đích (merge)
a = _ann('Tuy nh iên , anh ấy đến', 'Tuy nhiên , anh ấy đến')
assert [b['type'] for b in a['edit_blocks']] == ['merge'], a['edit_blocks']
assert a['error_positions'] == [1, 2]  # cả 2 token nguồn ("nh", "iên") đều thuộc vùng lỗi
assert a['correction_pairs'] == [{'error': 'nh iên', 'correction': 'nhiên', 'position': 1}]

# 2. Từ dính: 1 token nguồn → 2 token đích (split)
a = _ann('anh vàahệ em', 'anh và hệ em')
assert [b['type'] for b in a['edit_blocks']] == ['split'], a['edit_blocks']
assert a['error_positions'] == [1]

# 3. Ký tự thừa ở đầu từ — ở mức token là substitute 1-1
a = _ann('aNăng suất tăng', 'Năng suất tăng')
assert [b['type'] for b in a['edit_blocks']] == ['substitute']
assert a['correction_pairs'][0] == {'error': 'aNăng', 'correction': 'Năng', 'position': 0}

# 4. Substitution + token dấu câu độc lập (style VSEC: "sanh , sạch , đẹp")
a = _ann('giữ môi trường sanh , sạch , đẹp .', 'giữ môi trường xanh , sạch , đẹp .')
assert [b['type'] for b in a['edit_blocks']] == ['substitute']
assert a['edit_blocks'][0]['punct_only'] is False
assert a['error_positions'] == [3]

# 5. Câu sạch
a = _ann('câu này sạch , đúng chính tả .', 'câu này sạch , đúng chính tả .')
assert a['is_clean'] and a['error_positions'] == [] and a['correction_pairs'] == []
assert all(s['is_correct'] for s in a['syllable_annotations'])

# 6. Lỗi hoa/thường — case-sensitive nên là edit thật
a = _ann('chuyên tronG lĩnh vực', 'chuyên trong lĩnh vực')
assert [b['type'] for b in a['edit_blocks']] == ['substitute']

# 7. Thiếu âm tiết ở nguồn (insert): KHÔNG có error_positions, chỉ ở correction_pairs,
#    và không token nguồn nào bị đánh dấu is_correct=False
a = _ann('Anh đi học .', 'Anh đã đi học .')
assert [b['type'] for b in a['edit_blocks']] == ['insert']
assert a['error_positions'] == []
assert a['correction_pairs'] == [{'error': '', 'correction': 'đã', 'position': 1}]
assert all(s['is_correct'] for s in a['syllable_annotations'])

# 8. Thừa âm tiết ở nguồn (delete)
a = _ann('Anh rồi đi học .', 'Anh đi học .')
assert [b['type'] for b in a['edit_blocks']] == ['delete']
assert a['error_positions'] == [1]
assert a['correction_pairs'] == [{'error': 'rồi', 'correction': '', 'position': 1}]
assert a['syllable_annotations'][1]['is_correct'] is False
assert a['syllable_annotations'][1]['corrections'] == ['']

# 9. Khác chỉ dấu câu → block punct_only
a = _ann('Anh đến rồi .', 'Anh đến rồi ,')
assert [b['type'] for b in a['edit_blocks']] == ['substitute']
assert a['edit_blocks'][0]['punct_only'] is True

# 10. Tokenization canonical: dấu câu dính được tách, 2 vế về cùng hệ tọa độ
assert canon_tokenize('Anh đến,rồi.') == ['Anh', 'đến', ',', 'rồi', '.']
assert canon_tokenize('Đám "ong ve" của') == ['Đám', '"', 'ong', 've', '"', 'của']
assert canon_tokenize('Suzuki GSX-R 1000 2012') == ['Suzuki', 'GSX', '-', 'R', '1000', '2012']

print('Tất cả assert case biên PASS —', SHARED_CELLS_VERSION)
# Out:
# Tất cả assert case biên PASS — align-v1

# %% [markdown]
# ## 3. Kiểm chứng aligner trên gold VSEC — 3 tầng
#
# Chạy align `text ↔ corrected_text` trên **toàn bộ VSEC** (train+val, từ output nb0) rồi so với gold:
#
# - **(a) Count agreement**: số block == `error_count` gold, mọi câu. Lệch là bình thường khi 2 lỗi kề nhau gộp thành 1 block.
# - **(b) Pair containment (2 chiều)**: gold pair khớp nếu `canon_tokenize(error)` là token-subsequence **liền kề** trong `src_tokens` của block nào đó và `canon_tokenize(correction)` nằm trong `tgt_tokens` của cùng block. Báo recall (gold→block) + precision (block→gold) + tỉ lệ câu perfect.
# - **(c) Exact position**: `position` gold nằm trong `src_span` của block khớp — **chỉ tính trên câu có `len(ws_tokens) == len(canon_tokens)`** (tránh offset hệ thống do token canonical tách dấu câu dính như `đẹp.`).
#
# Đây là **tool-validation** (không fit tham số nào) → không liên quan leakage. Kỳ vọng không 100%: phần lệch gồm cả lỗi gold (edge case annotation, PROJECT.md §3.2) lẫn giới hạn aligner — in mẫu lệch ra để soi tay phân biệt.

# %%
def load_jsonl(path):
    with open(path, encoding='utf-8') as f:
        return [json.loads(line) for line in f if line.strip()]


def contains_contiguous(seq, sub):
    if not sub:
        return True
    L = len(sub)
    return any(seq[k:k + L] == sub for k in range(len(seq) - L + 1))


vsec_all = load_jsonl(INPUT_DIR / 'vsec_train.jsonl') + load_jsonl(INPUT_DIR / 'vsec_val.jsonl')
manifest_vsec_n = manifest_nb0.get('vsec', {}).get('after_dedupe')
if manifest_vsec_n is not None and len(vsec_all) != manifest_vsec_n:
    print(f'[CẢNH BÁO] Số câu VSEC ({len(vsec_all)}) ≠ manifest nb0 ({manifest_vsec_n}) — nb1 chỉ báo, không tự sửa nb0.')
else:
    print(f'VSEC: {len(vsec_all)} câu (train+val) — khớp manifest nb0')

tier = {
    'n_sentences': 0,
    'count_match': 0,                                          # tầng (a)
    'gold_pairs_total': 0, 'gold_pairs_matched': 0,            # tầng (b) — recall
    'blocks_total': 0, 'blocks_matched': 0,                     # tầng (b) — precision
    'pos_eligible_pairs': 0, 'pos_in_span': 0,                  # tầng (c)
    'perfect_sentences': 0,
}
mismatch_samples = []
vsec_pseudo = []  # list (record, annotation)

for rec in vsec_all:
    ann = build_pseudo_annotation(rec['text'], rec['corrected_text'])
    vsec_pseudo.append((rec, ann))
    blocks = ann['edit_blocks']
    gold_pairs = rec.get('correction_pairs') or []
    ws_len = len(nfc_normalize(rec['text']).split())
    canon_len = len(ann['src_tokens'])

    tier['n_sentences'] += 1
    if ann['error_count'] == rec.get('error_count'):
        tier['count_match'] += 1

    gold_matched = []
    block_matched = [False] * len(blocks)
    for gp in gold_pairs:
        e_toks = canon_tokenize(gp.get('error', ''))
        c_toks = canon_tokenize(gp.get('correction', ''))
        if not e_toks and not c_toks:
            continue  # gold pair rỗng lạ — bỏ qua, không vào mẫu số
        tier['gold_pairs_total'] += 1
        hit = None
        for bi, b in enumerate(blocks):
            if contains_contiguous(b['src_tokens'], e_toks) and contains_contiguous(b['tgt_tokens'], c_toks):
                hit = (bi, b)
                break
        if hit is None:
            gold_matched.append(False)
            continue
        bi, b = hit
        gold_matched.append(True)
        block_matched[bi] = True
        tier['gold_pairs_matched'] += 1
        if ws_len == canon_len and isinstance(gp.get('position'), int):
            tier['pos_eligible_pairs'] += 1
            if b['src_span'][0] <= gp['position'] < b['src_span'][1]:
                tier['pos_in_span'] += 1

    tier['blocks_total'] += len(blocks)
    tier['blocks_matched'] += sum(block_matched)
    if all(gold_matched) and all(block_matched) and ann['error_count'] == rec.get('error_count'):
        tier['perfect_sentences'] += 1
    elif len(mismatch_samples) < 20:
        mismatch_samples.append({
            'row_id': rec.get('row_id'), 'split': rec.get('split'), 'text': rec['text'][:100],
            'gold_error_count': rec.get('error_count'),
            'gold_pairs': [
                {'error': gp.get('error'), 'correction': gp.get('correction'), 'position': gp.get('position')}
                for gp in gold_pairs
            ],
            'pseudo_blocks': [
                {'type': b['type'], 'position': b['position'],
                 'src': ' '.join(b['src_tokens']) or '∅', 'tgt': ' '.join(b['tgt_tokens']) or '∅'}
                for b in blocks
            ],
        })

print('== Kiểm chứng aligner trên gold VSEC (3 tầng) ==')
print(f"(a) count agreement   : {tier['count_match']}/{tier['n_sentences']} câu ({tier['count_match'] / tier['n_sentences']:.1%})")
print(f"(b) recall gold pairs : {tier['gold_pairs_matched']}/{tier['gold_pairs_total']} ({tier['gold_pairs_matched'] / max(tier['gold_pairs_total'], 1):.1%})")
print(f"(b) precision blocks  : {tier['blocks_matched']}/{tier['blocks_total']} ({tier['blocks_matched'] / max(tier['blocks_total'], 1):.1%})")
print(f"(b) perfect sentences : {tier['perfect_sentences']}/{tier['n_sentences']} ({tier['perfect_sentences'] / tier['n_sentences']:.1%})")
print(f"(c) position in span  : {tier['pos_in_span']}/{tier['pos_eligible_pairs']} ({tier['pos_in_span'] / max(tier['pos_eligible_pairs'], 1):.1%}) — chỉ câu có len(ws)==len(canon)")
print()
print(f'Mẫu lệch (giữ tối đa {len(mismatch_samples)}) — soi để phân biệt lỗi gold vs lỗi aligner:')
for s in mismatch_samples:
    print(json.dumps(s, ensure_ascii=False))
# Out:
# VSEC: 9270 câu (train+val) — khớp manifest nb0
# == Kiểm chứng aligner trên gold VSEC (3 tầng) ==
# (a) count agreement   : 8970/9270 câu (96.8%)
# (b) recall gold pairs : 10702/11151 (96.0%)
# (b) precision blocks  : 10292/10782 (95.5%)
# (b) perfect sentences : 8489/9270 (91.6%)
# (c) position in span  : 67/67 (100.0%) — chỉ câu có len(ws)==len(canon)
#
# Mẫu lệch (giữ tối đa 20) — soi để phân biệt lỗi gold vs lỗi aligner:
# {"row_id": 784, "split": "train", "text": "Thuế GTGT cần đảm bảo ổn định và tăng dần tỷ trọng để đảm bảo nguồn thu NSNN đáp ứng nhu cầu chi tiê", "gold_error_count": 2, "gold_pairs": [{"error": "củ", "correction": "", "position": 24}, {"error": "a", "correction": "của", "position": 25}], "pseudo_blocks": [{"type": "merge", "position": 24, "src": "củ a", "tgt": "của"}]}
# {"row_id": 7692, "split": "train", "text": "Do hao mòn dần, nên người ta tiến hành sửa chữa hoặc thay thế các bộ phận của máy khi khả năng làm v", "gold_error_count": 1, "gold_pairs": [{"error": "nửa.", "correction": "nữa.", "position": 36}], "pseudo_blocks": [{"type": "substitute", "position": 37, "src": "nửa", "tgt": "nữa"}]}
# {"row_id": 8180, "split": "train", "text": "Những sản phẩm này không chỉ mang tính lí thuyết mà còn chưa scar những vấn đề xã hội.", "gold_error_count": 2, "gold_pairs": [{"error": "chưa", "correction": "chứa", "position": 12}, {"error": "scar", "correction": "cả", "position": 13}], "pseudo_blocks": [{"type": "multi", "position": 12, "src": "chưa scar", "tgt": "chứa cả"}]}
# {"row_id": 4242, "split": "train", "text": "Để trả lời câu hỏi đó, tôi đã và đang tìm hiểu về đề tàí này: \"Những yếu tố ảnh hưởng đến quyết định", "gold_error_count": 3, "gold_pairs": [{"error": "tàí", "correction": "tài", "position": 14}, {"error": "phảm", "correction": "phẩm", "position": 26}, {"error": "của", "correction": "cửa", "position": 27}], "pseudo_blocks": [{"type": "substitute", "position": 15, "src": "tàí", "tgt": "tài"}, {"type": "multi", "position": 29, "src": "phảm của", "tgt": "phẩm cửa"}]}
# {"row_id": 7365, "split": "train", "text": "Sử dụng một từ khóa trong mỗi dòng đọc đuwowcj.", "gold_error_count": 1, "gold_pairs": [{"error": "đuwowcj.", "correction": "được.", "position": 9}], "pseudo_blocks": [{"type": "substitute", "position": 9, "src": "đuwowcj", "tgt": "được"}]}
# {"row_id": 9016, "split": "train", "text": "Việc đọc trở thành một khoản đầu tư đầy giá trị và mạng lợi \"lợi nhuận\" lớn cho cuộc đời họ.", "gold_error_count": 2, "gold_pairs": [{"error": "mạng", "correction": "mang", "position": 12}, {"error": "lợi", "correction": "lại", "position": 13}], "pseudo_blocks": [{"type": "multi", "position": 12, "src": "mạng lợi", "tgt": "mang lại"}]}
# {"row_id": 1501, "split": "train", "text": "Chè có giá trị sử dụng và là hàng hóa có giá trị kinh tế, sản xuất chè mang lại hiệu quả kinh tế khá", "gold_error_count": 1, "gold_pairs": [{"error": "chung..", "correction": "chung.", "position": 44}], "pseudo_blocks": [{"type": "substitute", "position": 47, "src": "..", "tgt": "."}]}
# {"row_id": 622, "split": "train", "text": "Xem xét sai lệch các góc nhiều hay ít và tình trạng hiện tại của xe để tiến hành sửa chửa.", "gold_error_count": 1, "gold_pairs": [{"error": "chửa.", "correction": "chữa.", "position": 20}], "pseudo_blocks": [{"type": "substitute", "position": 20, "src": "chửa", "tgt": "chữa"}]}
# {"row_id": 9305, "split": "train", "text": "Tuy nhiên, Tòa án cũng không đưa ra được lập luận thuyết phục trong việc lựa chọn mức bồi thường như", "gold_error_count": 1, "gold_pairs": [{"error": "trên,", "correction": "trên.", "position": 21}], "pseudo_blocks": [{"type": "substitute", "position": 23, "src": ",", "tgt": "."}]}
# {"row_id": 7022, "split": "train", "text": "Excel được định dạng theo khuôn mẫu như bảng để thuận tiện cho việc hiển thị và so sánh dữ liệu của ", "gold_error_count": 1, "gold_pairs": [{"error": "dung.", "correction": "dùng.", "position": 23}], "pseudo_blocks": [{"type": "substitute", "position": 23, "src": "dung", "tgt": "dùng"}]}
# {"row_id": 2573, "split": "train", "text": "Luật chơi rõ ràng, dễ hểu.", "gold_error_count": 1, "gold_pairs": [{"error": "hểu.", "correction": "hiểu.", "position": 5}], "pseudo_blocks": [{"type": "substitute", "position": 6, "src": "hểu", "tgt": "hiểu"}]}
# {"row_id": 5204, "split": "train", "text": "Dự án đầu tư xây dựng và kinh doanh khu sân golf và biệt thử Tảm Đảo, a.", "gold_error_count": 2, "gold_pairs": [{"error": "thử", "correction": "thự", "position": 14}, {"error": "Tảm", "correction": "Tam", "position": 15}], "pseudo_blocks": [{"type": "multi", "position": 14, "src": "thử Tảm", "tgt": "thự Tam"}]}
# {"row_id": 9326, "split": "train", "text": "Vị trí đặc điểm địa hình khiến Việt Nam là một trong những nước chịu nhiều thiên tai nhất trên thế g", "gold_error_count": 2, "gold_pairs": [{"error": "xâm", "correction": "xâm nhập", "position": 29}, {"error": "sảy", "correction": "xảy", "position": 40}], "pseudo_blocks": [{"type": "insert", "position": 32, "src": "∅", "tgt": "nhập"}, {"type": "substitute", "position": 42, "src": "sảy", "tgt": "xảy"}]}
# {"row_id": 7760, "split": "train", "text": "Cơ cấu phanh bị ướt có thể là do khi chuyển động trên đường ướt và lội qua những chỗ ngập nươc, cũng", "gold_error_count": 1, "gold_pairs": [{"error": "nươc,", "correction": "nước,", "position": 21}], "pseudo_blocks": [{"type": "substitute", "position": 21, "src": "nươc", "tgt": "nước"}]}
# {"row_id": 7888, "split": "train", "text": "Việt Nam ngày càng hội nhập sâu rộng vào nền kinh tế thế giới và được tính nhiệm giữa nhiều vai trò ", "gold_error_count": 4, "gold_pairs": [{"error": "tính", "correction": "tín", "position": 16}, {"error": "giữa", "correction": "giữ", "position": 18}, {"error": "bươc", "correction": "bước", "position": 27}, {"error": "skhawngr", "correction": "khẳng", "position": 28}], "pseudo_blocks": [{"type": "substitute", "position": 16, "src": "tính", "tgt": "tín"}, {"type": "substitute", "position": 18, "src": "giữa", "tgt": "giữ"}, {"type": "multi", "position": 28, "src": "bươc skhawngr", "tgt": "bước khẳng"}]}
# {"row_id": 5033, "split": "train", "text": "Người xưa có câu \"Học thầy không tày học ạn\", ởi lẽ đó phong trào \"Đôi ạn cùng tiến\" mang ý nghĩa nh", "gold_error_count": 3, "gold_pairs": [{"error": "ạn\",", "correction": "bạn", "position": 9}, {"error": "ởi", "correction": "bởi", "position": 10}, {"error": "ạn", "correction": "bạn", "position": 16}], "pseudo_blocks": [{"type": "multi", "position": 10, "src": "ạn \", ởi", "tgt": "bạn bởi"}, {"type": "substitute", "position": 19, "src": "ạn", "tgt": "bạn"}]}
# {"row_id": 6440, "split": "train", "text": "a) Đường kinh xi lanh công tác banh xe.", "gold_error_count": 3, "gold_pairs": [{"error": "kinh", "correction": "kính", "position": 2}, {"error": "tác", "correction": "tắc", "position": 6}, {"error": "banh", "correction": "bánh", "position": 7}], "pseudo_blocks": [{"type": "substitute", "position": 3, "src": "kinh", "tgt": "kính"}, {"type": "multi", "position": 7, "src": "tác banh", "tgt": "tắc bánh"}]}
# {"row_id": 5317, "split": "train", "text": "Thông báo cáo tài chính hàng năm của công ty và quyết đinh mức chia cổ tức cho cổ đông thành viên Hộ", "gold_error_count": 2, "gold_pairs": [{"error": "báo", "correction": "báo báo", "position": 1}, {"error": "đinh", "correction": "định", "position": 12}], "pseudo_blocks": [{"type": "insert", "position": 1, "src": "∅", "tgt": "báo"}, {"type": "substitute", "position": 12, "src": "đinh", "tgt": "định"}]}
# {"row_id": 5629, "split": "train", "text": "Việt Nam với các tờ báo như Nhân dân, báo Lao đông, Sài Gòn giải phóng,... đều là những tờ báo có tê", "gold_error_count": 2, "gold_pairs": [{"error": "đông,", "correction": "động,", "position": 11}, {"error": "vu", "correction": "vụ", "position": 44}], "pseudo_blocks": [{"type": "substitute", "position": 12, "src": "đông", "tgt": "động"}, {"type": "substitute", "position": 48, "src": "vu", "tgt": "vụ"}]}
# {"row_id": 7383, "split": "train", "text": "V ấn đề này khiến cho SDN switch của hãng này không thể kết nối được với SDN controller của hãng khá", "gold_error_count": 2, "gold_pairs": [{"error": "V", "correction": "", "position": 0}, {"error": "ấn", "correction": "Vấn", "position": 1}], "pseudo_blocks": [{"type": "merge", "position": 0, "src": "V ấn", "tgt": "Vấn"}]}

# %% [markdown]
# ## 4. Align test 6k
#
# Load `test_normalized.jsonl`, đối chiếu số câu với `manifest.json` của nb0 (lệch → **chỉ báo cáo, không tự sửa nb0**), rồi align từng cặp `text ↔ corrected_text` → pseudo-annotation. `align_failed` tuyệt đối (một vế token hóa rỗng) được đếm riêng.

# %%
test_records = load_jsonl(INPUT_DIR / 'test_normalized.jsonl')
manifest_test_n = manifest_nb0.get('test', {}).get('after_dedupe')
if manifest_test_n is not None and len(test_records) != manifest_test_n:
    print(f'[CẢNH BÁO] Số câu test ({len(test_records)}) ≠ manifest nb0 ({manifest_test_n}) — nb1 chỉ báo, không tự sửa nb0.')
else:
    print(f'Test: {len(test_records)} câu — khớp manifest nb0')

test_aligned = []
for rec in test_records:
    ann = build_pseudo_annotation(rec['text'], rec['corrected_text'])
    test_aligned.append({**rec, 'pseudo': ann})

n_fail = sum(1 for r in test_aligned if r['pseudo']['align_failed'])
print(f'Đã align {len(test_aligned)} câu · align_failed tuyệt đối: {n_fail}')
# Out:
# Test: 5983 câu — khớp manifest nb0
# Đã align 5983 câu · align_failed tuyệt đối: 0

# %% [markdown]
# ## 5. Roundtrip invariant — assert 100%
#
# Với **mọi câu** (VSEC + test): thay các edit block vào token nguồn phải thu về đúng token đích, và mọi `error_positions` nằm trong range. Đây là kiểm chứng cấu trúc của aligner (phủ kín, không chồng lấn, index hợp lệ) trước khi pseudo-annotation được dùng làm gold cho eval ở nb3.

# %%
n_checked = 0
for rec, ann in vsec_pseudo:
    assert apply_edit_blocks(ann['src_tokens'], ann['edit_blocks']) == ann['tgt_tokens'], rec.get('row_id')
    assert all(0 <= p < len(ann['src_tokens']) for p in ann['error_positions']), rec.get('row_id')
    n_checked += 1
for r in test_aligned:
    a = r['pseudo']
    assert apply_edit_blocks(a['src_tokens'], a['edit_blocks']) == a['tgt_tokens'], r.get('text', '')[:60]
    assert all(0 <= p < len(a['src_tokens']) for p in a['error_positions'])
    n_checked += 1
print(f'Roundtrip invariant PASS 100% — {n_checked} câu (VSEC + test): src + edit_blocks == tgt, mọi vị trí trong range.')
# Out:
# Roundtrip invariant PASS 100% — 15253 câu (VSEC + test): src + edit_blocks == tgt, mọi vị trí trong range.

# %% [markdown]
# ## 6. Thống kê bộ test sau align
#
# Số liệu then chốt: **tỉ lệ câu sạch** (câu không phát sinh edit — trả lời câu hỏi treo DESIGN.md §11.1, và quyết định có thêm chỉ số "tỷ lệ giữ nguyên câu sạch" ở DESIGN.md §6 hay không), tỉ lệ suspect, phân bố loại edit, phân bố số lỗi/câu so với gold VSEC.

# %%
import collections


def error_bins(n):
    return '0' if n == 0 else ('1' if n == 1 else ('2' if n == 2 else ('3' if n == 3 else '>=4')))


def summarize(records, ann_get):
    s = {
        'n': len(records),
        'clean': 0, 'clean_strict': 0, 'suspect': 0, 'align_failed': 0,
        'block_types': collections.Counter(), 'punct_only_blocks': 0, 'only_punct_sentences': 0,
        'error_bins': collections.Counter(),
    }
    for r in records:
        a = ann_get(r)
        s['clean'] += a['is_clean']
        s['clean_strict'] += a['is_clean'] and not a['suspect']
        s['suspect'] += a['suspect']
        s['align_failed'] += a['align_failed']
        s['block_types'].update(b['type'] for b in a['edit_blocks'])
        s['punct_only_blocks'] += sum(1 for b in a['edit_blocks'] if b['punct_only'])
        if a['edit_blocks'] and all(b['punct_only'] for b in a['edit_blocks']):
            s['only_punct_sentences'] += 1
        s['error_bins'][error_bins(a['error_count'])] += 1
    return s


test_sum = summarize(test_aligned, lambda r: r['pseudo'])
vsec_sum = summarize(vsec_pseudo, lambda t: t[1])
vsec_gold_bins = collections.Counter(error_bins(rec.get('error_count') or 0) for rec, _ in vsec_pseudo)

n = test_sum['n']
print('== Thống kê bộ test sau align ==')
print(f'Tổng số câu                  : {n}')
print(f"Câu sạch (0 edit)            : {test_sum['clean']} ({test_sum['clean'] / n:.1%})  ← trả lời DESIGN.md §11.1")
print(f"Câu sạch loại suspect        : {test_sum['clean_strict']} ({test_sum['clean_strict'] / n:.1%})")
print(f"Câu suspect (edit dày)       : {test_sum['suspect']} ({test_sum['suspect'] / n:.1%})")
print(f"Align failed tuyệt đối       : {test_sum['align_failed']}")
print(f"Câu chỉ khác dấu câu         : {test_sum['only_punct_sentences']} · block punct_only: {test_sum['punct_only_blocks']}")
print()
print('Phân bố loại edit block (test):')
for t, c in test_sum['block_types'].most_common():
    print(f'  {t:12s}: {c}')
print()
print('Phân bố số lỗi/câu — test (pseudo, số block) vs VSEC (gold):')
for b in ['0', '1', '2', '3', '>=4']:
    print(f"  {b:4s}: test {test_sum['error_bins'][b]:5d} ({test_sum['error_bins'][b] / n:.1%})"
          f" · VSEC {vsec_gold_bins[b]:5d} ({vsec_gold_bins[b] / vsec_sum['n']:.1%})")
# Out:
# == Thống kê bộ test sau align ==
# Tổng số câu                  : 5983
# Câu sạch (0 edit)            : 653 (10.9%)  ← trả lời DESIGN.md §11.1
# Câu sạch loại suspect        : 653 (10.9%)
# Câu suspect (edit dày)       : 2316 (38.7%)
# Align failed tuyệt đối       : 0
# Câu chỉ khác dấu câu         : 0 · block punct_only: 9
#
# Phân bố loại edit block (test):
#   substitute  : 18959
#   multi       : 2729
#   split       : 176
#   insert      : 73
#   merge       : 1
#
# Phân bố số lỗi/câu — test (pseudo, số block) vs VSEC (gold):
#   0   : test   653 (10.9%) · VSEC     0 (0.0%)
#   1   : test   672 (11.2%) · VSEC  7796 (84.1%)
#   2   : test   952 (15.9%) · VSEC  1210 (13.1%)
#   3   : test   914 (15.3%) · VSEC   191 (2.1%)
#   >=4 : test  2792 (46.7%) · VSEC    73 (0.8%)

# %% [markdown]
# ## 7. QA 50 mẫu — in ra soát tay
#
# Chọn mẫu **seeded** (`random.Random(SEED)`) stratified: clean / substitute / insert / delete / split / merge / punct_only / suspect — stratum thiếu thì thay bằng random. Khi soát tay từng mẫu cần kiểm:
#
# 1. Span `[...]` đánh dấu có đúng chỗ lỗi thật không?
# 2. `correction` của block có đúng với ý nghĩa câu đã sửa không?
# 3. Block `merge`/`split`/`multi` có phải từ dính/tách sai/cụm lỗi cần xử lý riêng không?
# 4. Câu `suspect` có phải align sai (2 vế không thật sự song song) hay bản thân cặp dữ liệu gốc đã lỗi?
#
# Danh sách mẫu cũng được ghi vào `qa_samples.json` để đối chiếu lại sau.

# %%
import random

STRATA_QUOTAS = [
    ('clean', 10), ('substitute', 10), ('insert', 5), ('delete', 5),
    ('split', 5), ('merge', 5), ('punct_only', 5), ('suspect', 5),
]


def stratum_tags(a):
    tags = set()
    if a['is_clean']:
        tags.add('clean')
    if a['suspect']:
        tags.add('suspect')
    for b in a['edit_blocks']:
        tags.add('punct_only' if b['punct_only'] else b['type'])
    return tags


rng = random.Random(SEED)
picked = {}
for stratum, quota in STRATA_QUOTAS:
    cands = [i for i, r in enumerate(test_aligned) if i not in picked and stratum in stratum_tags(r['pseudo'])]
    for i in rng.sample(cands, min(quota, len(cands))):
        picked[i] = stratum
if len(picked) < QA_N:
    rest = [i for i in range(len(test_aligned)) if i not in picked]
    for i in rng.sample(rest, min(QA_N - len(picked), len(rest))):
        picked[i] = 'random'


def render_marked(tokens, blocks, side):
    marked = set()
    for b in blocks:
        lo, hi = b['src_span'] if side == 'src' else b['tgt_span']
        marked.update(range(lo, hi))
    return ' '.join(f'[{t}]' if i in marked else t for i, t in enumerate(tokens))


qa_samples = []
for i in sorted(picked):
    r = test_aligned[i]
    a = r['pseudo']
    print(f"—— QA idx={i} · stratum={picked[i]} · clean={a['is_clean']} · suspect={a['suspect']} · edit_ratio={a['edit_ratio']}")
    print('  SRC:', render_marked(a['src_tokens'], a['edit_blocks'], 'src'))
    print('  TGT:', render_marked(a['tgt_tokens'], a['edit_blocks'], 'tgt'))
    for b in a['edit_blocks']:
        note = ' (punct_only)' if b['punct_only'] else ''
        src_s = ' '.join(b['src_tokens']) or '∅'
        tgt_s = ' '.join(b['tgt_tokens']) or '∅'
        print(f"    - {b['type']}@{b['position']}: {src_s} → {tgt_s}{note}")
    print()
    qa_samples.append({'test_index': i, 'stratum': picked[i], 'text': r['text'],
                       'corrected_text': r['corrected_text'], 'pseudo': a})

print(f'Đã in {len(qa_samples)} mẫu QA (mục tiêu {QA_N}, seed {SEED}) để soát tay.')
# Out:
# —— QA idx=202 · stratum=clean · clean=True · suspect=False · edit_ratio=0.0
#   SRC: Hôm vụ cướp xảy ra , Củ Chi mưa tầm tã .
#   TGT: Hôm vụ cướp xảy ra , Củ Chi mưa tầm tã .
#
# —— QA idx=260 · stratum=substitute · clean=False · suspect=True · edit_ratio=0.4
#   SRC: Vì sao khi mang bầu [chaan] lại to [leen] ?
#   TGT: Vì sao khi mang bầu [chân] lại to [lên] ?
#     - substitute@5: chaan → chân
#     - substitute@8: leen → lên
#
# —— QA idx=293 · stratum=substitute · clean=False · suspect=True · edit_ratio=0.32
#   SRC: Tuy nhiên , so với mặt bằng xây dựng hiện [tạe] thì [mxc] giá mà chủ đầu tư [đfl] ra vẫn ở mức [kao] .
#   TGT: Tuy nhiên , so với mặt bằng xây dựng hiện [tại] thì [mức] giá mà chủ đầu tư [đưa] ra vẫn ở mức [cao] .
#     - substitute@10: tạe → tại
#     - substitute@12: mxc → mức
#     - substitute@18: đfl → đưa
#     - substitute@23: kao → cao
#
# —— QA idx=312 · stratum=substitute · clean=False · suspect=False · edit_ratio=0.0282
#   SRC: Liên quan đến vụ thi hành cưỡng chế nhà tại địa chỉ 105 bis Nguyễn Văn Cừ , quận Ninh Kiều , TP . Cần Thơ , ngày 2 - 11 Cục Thi hành án dân sự TP . Cần Thơ cho [bít] đã có quyết định tổ chức cưỡng chế , trục xuất những người chiếm giữ căn nhà vào ngày 25 - 11 để thực hiện bản án .
#   TGT: Liên quan đến vụ thi hành cưỡng chế nhà tại địa chỉ 105 bis Nguyễn Văn Cừ , quận Ninh Kiều , TP . Cần Thơ , ngày 2 - 11 Cục Thi hành án dân sự TP . Cần Thơ cho [biết] đã có quyết định tổ chức cưỡng chế , trục xuất những người chiếm giữ căn nhà vào ngày 25 - 11 để thực hiện bản án .
#     - substitute@42: bít → biết
#
# —— QA idx=359 · stratum=random · clean=False · suspect=False · edit_ratio=0.2025
#   SRC: [Giự] báo , đến [nghày] 7 . 11 , mực nước cao nhất [nghày] [chên] sông Tiền tại Tân [Trâu] xuống mức 3 , 75m ( dưới báo động 2 là 0 , 25m ), [chên] sông Hậu tại [Trâu] Đốc xuống mức 3 , 4m ( dưới báo động 2 là 0 , 1m ), [chên] sông Vàm Cỏ Tây tại Mộc Hóa xuống mức 2 , 45m ( trên báo động 3 là 0 , 05m ).
#   TGT: [Dự] báo , đến [ngày] 7 . 11 , mực nước cao nhất [ngày] [trên] sông Tiền tại Tân [Châu] xuống mức 3 , 75m ( dưới báo động 2 là 0 , 25m ), [trên] sông Hậu tại [Châu] Đốc xuống mức 3 , 4m ( dưới báo động 2 là 0 , 1m ), [trên] sông Vàm Cỏ Tây tại Mộc Hóa xuống mức 2 , 45m ( trên báo động 3 là 0 , 05m ).
#     - substitute@0: Giự → Dự
#     - substitute@4: nghày → ngày
#     - multi@13: nghày chên → ngày trên
#     - substitute@19: Trâu → Châu
#     - substitute@35: chên → trên
#     - substitute@39: Trâu → Châu
#     - substitute@56: chên → trên
#
# —— QA idx=743 · stratum=clean · clean=True · suspect=False · edit_ratio=0.0
#   SRC: Chủ tịch Khu Bun Hui nêu rõ , những khó khăn trong công tác phòng , chống tội phạm xuyên quốc gia mà In - tơ - pôn đang phải đương đầu , đó là , các loại tội phạm rửa tiền , buôn bán người , trẻ em , buôn bán ma túy , vũ khí , cướp biển , chống tội phạm công nghệ cao , chống tội phạm có tổ chức , chống khủng bố ... Điều đó đòi hỏi các hoạt động của In - tơ - pôn phải sáng tạo , tăng cường thêm biện pháp và năng động hơn về mặt tài chính , đổi mới công nghệ giúp In - tơ - pôn ứng phó với những thách thức toàn cầu trong thế kỷ 21 về phòng , chống tội phạm .
#   TGT: Chủ tịch Khu Bun Hui nêu rõ , những khó khăn trong công tác phòng , chống tội phạm xuyên quốc gia mà In - tơ - pôn đang phải đương đầu , đó là , các loại tội phạm rửa tiền , buôn bán người , trẻ em , buôn bán ma túy , vũ khí , cướp biển , chống tội phạm công nghệ cao , chống tội phạm có tổ chức , chống khủng bố ... Điều đó đòi hỏi các hoạt động của In - tơ - pôn phải sáng tạo , tăng cường thêm biện pháp và năng động hơn về mặt tài chính , đổi mới công nghệ giúp In - tơ - pôn ứng phó với những thách thức toàn cầu trong thế kỷ 21 về phòng , chống tội phạm .
#
# —— QA idx=797 · stratum=random · clean=False · suspect=False · edit_ratio=0.2963
#   SRC: Ngôi nhà Baniszewski Tuy nhiên , những [buwxa] ăn tại gia đình Baniszewski có thể [dduwợc] coi là kinh [hoafng] nhất mà [coo] từng được ăn .
#   TGT: Ngôi nhà Baniszewski Tuy nhiên , những [bữa] ăn tại gia đình Baniszewski có thể [được] coi là kinh [hoàng] nhất mà [cô] từng được ăn .
#     - substitute@7: buwxa → bữa
#     - substitute@15: dduwợc → được
#     - substitute@19: hoafng → hoàng
#     - substitute@22: coo → cô
#
# —— QA idx=898 · stratum=substitute · clean=False · suspect=True · edit_ratio=0.4444
#   SRC: [Awn] cá [ist] nhất 2 lần mỗi tuần .
#   TGT: [Ăn] cá [ít] nhất 2 lần mỗi tuần .
#     - substitute@0: Awn → Ăn
#     - substitute@2: ist → ít
#
# —— QA idx=909 · stratum=clean · clean=True · suspect=False · edit_ratio=0.0
#   SRC: Bài bình + Video U23 Việt Nam U23 Philippines : Hai nửa vui buồn .
#   TGT: Bài bình + Video U23 Việt Nam U23 Philippines : Hai nửa vui buồn .
#
# —— QA idx=959 · stratum=suspect · clean=False · suspect=True · edit_ratio=0.3158
#   SRC: [Nhữnvg] điều [bàui] viết nêu ra , hẳn nhiên , cũng chỉ là một phần rất nhỏ về một con người xét [riênh] [t5ên] khía cạnh tâm [uồn] , cách ứng xử giữa bạn bè với [nmhau] .
#   TGT: [Những] điều [bài] viết nêu ra , hẳn nhiên , cũng chỉ là một phần rất nhỏ về một con người xét [riêng] [trên] khía cạnh tâm [hồn] , cách ứng xử giữa bạn bè với [nhau] .
#     - substitute@0: Nhữnvg → Những
#     - substitute@2: bàui → bài
#     - multi@22: riênh t5ên → riêng trên
#     - substitute@27: uồn → hồn
#     - substitute@36: nmhau → nhau
#
# —— QA idx=1016 · stratum=clean · clean=True · suspect=False · edit_ratio=0.0
#   SRC: Bốn tên cướp nhặt túi vàng , lên xe máy chạy trốn mất dạng trong màn mưa .
#   TGT: Bốn tên cướp nhặt túi vàng , lên xe máy chạy trốn mất dạng trong màn mưa .
#
# —— QA idx=1031 · stratum=random · clean=False · suspect=True · edit_ratio=0.3226
#   SRC: Trong khi đó , [aànu] chục ngàn DN đã phá sản [uoặc] dừng [san] xuất vì khó khăn mà trong đó [hhi] phí vốn cao là nguyên nhân [đku] tiên .
#   TGT: Trong khi đó , [hàng] chục ngàn DN đã phá sản [hoặc] dừng [sản] xuất vì khó khăn mà trong đó [chi] phí vốn cao là nguyên nhân [đầu] tiên .
#     - substitute@4: aànu → hàng
#     - substitute@11: uoặc → hoặc
#     - substitute@13: san → sản
#     - substitute@21: hhi → chi
#     - substitute@28: đku → đầu
#
# —— QA idx=1061 · stratum=suspect · clean=False · suspect=True · edit_ratio=0.4
#   SRC: Chùm [ảnjh] chiến thắng của U23 [V] trước Philippines .
#   TGT: Chùm [ảnh] chiến thắng của U23 [VN] trước Philippines .
#     - substitute@1: ảnjh → ảnh
#     - substitute@6: V → VN
#
# —— QA idx=1289 · stratum=clean · clean=True · suspect=False · edit_ratio=0.0
#   SRC: Đây là tình huống lần đầu tiên xảy ra .
#   TGT: Đây là tình huống lần đầu tiên xảy ra .
#
# —— QA idx=1412 · stratum=insert · clean=False · suspect=False · edit_ratio=0.2857
#   SRC: Tình trạng nợ bảo [jiểm] xã [hộ8i] ( của các DN đối với người lao động ở nước [6ta] hiện đang ở mức báo [độnjg] , năm sau cao hơn năm trước .
#   TGT: Tình trạng nợ bảo [hiểm] xã [hội] ( [BHXH] [)] của các DN đối với người lao động ở nước [ta] hiện đang ở mức báo [động] , năm sau cao hơn năm trước .
#     - substitute@4: jiểm → hiểm
#     - substitute@6: hộ8i → hội
#     - insert@8: ∅ → BHXH )
#     - substitute@18: 6ta → ta
#     - substitute@24: độnjg → động
#
# —— QA idx=1964 · stratum=clean · clean=True · suspect=False · edit_ratio=0.0
#   SRC: Quy định này sẽ tạo sự linh hoạt trong việc quy định thẩm quyền xử phạt nhưng vẫn đảm bảo khống chế mức phạt tiền tối đa đối với từng chức danh có thẩm quyền xử phạt .
#   TGT: Quy định này sẽ tạo sự linh hoạt trong việc quy định thẩm quyền xử phạt nhưng vẫn đảm bảo khống chế mức phạt tiền tối đa đối với từng chức danh có thẩm quyền xử phạt .
#
# —— QA idx=2104 · stratum=clean · clean=True · suspect=False · edit_ratio=0.0
#   SRC: Nước này cũng bị nạn tăng trưởng u ám và gia tăng bất bình đẳng .
#   TGT: Nước này cũng bị nạn tăng trưởng u ám và gia tăng bất bình đẳng .
#
# —— QA idx=2111 · stratum=substitute · clean=False · suspect=False · edit_ratio=0.2222
#   SRC: Nội dung kế hoạch chưa [đc] công bố .
#   TGT: Nội dung kế hoạch chưa [được] công bố .
#     - substitute@5: đc → được
#
# —— QA idx=2136 · stratum=merge · clean=False · suspect=True · edit_ratio=0.3488
#   SRC: [Ôjg] Phúc cho biết Vinapco cũng đã gửi đơn kiện Indochina Airlines đến [tva] kinh tế TPHCM để đòi khoản nợ trên nhưng cũng [khôwg] chắc sẽ đòi được vì [ônv] [chu] rằng " hãng lấy tiền [đâr] ra mà trả ["] [g]
#   TGT: [Ông] Phúc cho biết Vinapco cũng đã gửi đơn kiện Indochina Airlines đến [tòa] kinh tế TPHCM để đòi khoản nợ trên nhưng cũng [không] chắc sẽ đòi được vì [ông] [cho] rằng " hãng lấy tiền [đâu] ra mà trả [".]
#     - substitute@0: Ôjg → Ông
#     - substitute@13: tva → tòa
#     - substitute@24: khôwg → không
#     - multi@30: ônv chu → ông cho
#     - substitute@37: đâr → đâu
#     - merge@41: " g → ".
#
# —— QA idx=2182 · stratum=random · clean=False · suspect=False · edit_ratio=0.2703
#   SRC: Do đó , hãng này tuyên bố đã cố [gawsng] [giarm] số lượng [sarn] phẩm chứa chất bảo quản thải ra formaldehyde đến 33 % trên phạm vi toàn cầu và [hown] 60 % [taji] Mỹ .
#   TGT: Do đó , hãng này tuyên bố đã cố [gắng] [giảm] số lượng [sản] phẩm chứa chất bảo quản thải ra formaldehyde đến 33 % trên phạm vi toàn cầu và [hơn] 60 % [tại] Mỹ .
#     - multi@9: gawsng giarm → gắng giảm
#     - substitute@13: sarn → sản
#     - substitute@31: hown → hơn
#     - substitute@34: taji → tại
#
# —— QA idx=2206 · stratum=split · clean=False · suspect=False · edit_ratio=0.3
#   SRC: Nguy cơ gian lận thương mại lớn [vể] được công [nhyn] C / O hưởng ưu đãi thuế doanh [ngbigp] đang [gjp] rất nhiều khó khăn , chịu nhiều thiệt thòi Việc [knểm] tra [Clk] hàng nhập khẩu đã khó , việc cấp [pà] quản C / O hàng xuất [ehẩu] cũng đang gặp nhiều gian nan .
#   TGT: Nguy cơ gian lận thương mại lớn [Để] được công [nhận] C / O hưởng ưu đãi thuế doanh [nghiệp] đang [gặp] rất nhiều khó khăn , chịu nhiều thiệt thòi Việc [kiểm] tra [C] [/] [O] hàng nhập khẩu đã khó , việc cấp [và] quản C / O hàng xuất [khẩu] cũng đang gặp nhiều gian nan .
#     - substitute@7: vể → Để
#     - substitute@10: nhyn → nhận
#     - substitute@19: ngbigp → nghiệp
#     - substitute@21: gjp → gặp
#     - substitute@32: knểm → kiểm
#     - split@34: Clk → C / O
#     - substitute@43: pà → và
#     - substitute@50: ehẩu → khẩu
#
# —— QA idx=2234 · stratum=substitute · clean=False · suspect=False · edit_ratio=0.2963
#   SRC: Tuy [nhieen] , chính sách [cura] chính phủ Việt Nam thể hiện quan điểm của Chính phủ về một vấn đề [cuj] thể , và quan điểm này [sex] chỉ đạo hướng can [thieejp] của Chính phủ và cuối cùng [cos] [theer] được hiện thực hóa bằng việc ban hành một quy [đijnh] .
#   TGT: Tuy [nhiên] , chính sách [của] chính phủ Việt Nam thể hiện quan điểm của Chính phủ về một vấn đề [cụ] thể , và quan điểm này [sẽ] chỉ đạo hướng can [thiệp] của Chính phủ và cuối cùng [có] [thể] được hiện thực hóa bằng việc ban hành một quy [định] .
#     - substitute@1: nhieen → nhiên
#     - substitute@5: cura → của
#     - substitute@21: cuj → cụ
#     - substitute@28: sex → sẽ
#     - substitute@33: thieejp → thiệp
#     - multi@40: cos theer → có thể
#     - substitute@52: đijnh → định
#
# —— QA idx=2315 · stratum=suspect · clean=False · suspect=True · edit_ratio=0.3333
#   SRC: [Nhaan] lực nào không thuộc nhóm " tinh [giarn] biên chế "?
#   TGT: [Nhân] lực nào không thuộc nhóm " tinh [giản] biên chế "?
#     - substitute@0: Nhaan → Nhân
#     - substitute@8: giarn → giản
#
# —— QA idx=2413 · stratum=clean · clean=True · suspect=False · edit_ratio=0.0
#   SRC: Năm 2007 , quận Toyocho thuộc phía nam đảo Shikoku , đã đáp ứng đề nghị , nhưng sau khi bị phản đối đã rút lại quyết định .
#   TGT: Năm 2007 , quận Toyocho thuộc phía nam đảo Shikoku , đã đáp ứng đề nghị , nhưng sau khi bị phản đối đã rút lại quyết định .
#
# —— QA idx=2640 · stratum=punct_only · clean=False · suspect=False · edit_ratio=0.2771
#   SRC: Đồng thời , BHXH Việt Nam có văn bản gửi các quan chức năng đề nghị bổ sung hành vi cố [tyình] [njợ] [cây] dưa BHXH đối [vcới] chủ DN là cấu [tjhành] tội phạm hình sự , nâng mức xử phạt hành chính [fương] ứng [gvới] số tiền nợ BHXH ; Sửa đổi Điều 92 của Luật BHXH quy định để lại 2 số thu [H] [ytại] đơn [gvị] sử dụng chi chế [đ] ốm đau cho người lao động .
#   TGT: Đồng thời , BHXH Việt Nam có văn bản gửi các quan chức năng đề nghị bổ sung hành vi cố [tình] [nợ] [dây] dưa BHXH đối [với] chủ DN là cấu [thành] tội phạm hình sự , nâng mức xử phạt hành chính [tương] ứng [với] số tiền nợ BHXH ; Sửa đổi Điều 92 của Luật BHXH quy định để lại 2 [%] số thu [BHXH] [tại] đơn [vị] sử dụng chi chế [độ] ốm đau cho người lao động .
#     - multi@21: tyình njợ cây → tình nợ dây
#     - substitute@27: vcới → với
#     - substitute@32: tjhành → thành
#     - substitute@44: fương → tương
#     - substitute@46: gvới → với
#     - insert@64: ∅ → % (punct_only)
#     - multi@66: H ytại → BHXH tại
#     - substitute@69: gvị → vị
#     - substitute@74: đ → độ
#
# —— QA idx=2732 · stratum=punct_only · clean=False · suspect=False · edit_ratio=0.2857
#   SRC: Góp ý cho [qut] [địng] về nghĩa vụ và quyền quản lý và bảo vệ đối với các [nguiồn] nước liên quốc [goia] , đại [biểiu] Nguyễn [Ngọxc] Hòa , đề nghị : Vấn đề khai thác nước dưới đất cũng được nhiều đại biểu quan tâm , tập trung [vóp] ý . Trong Dự thảo quy định việc [tyăm] dò khai thác nước [cdưới] [đấ5t] với quy mô nhỏ không [cxần] phải xin phép [,] quy định này không được rõ ràng .
#   TGT: Góp ý cho [quy] [định] về nghĩa vụ và quyền quản lý và bảo vệ đối với các [nguồn] nước liên quốc [gia] , đại [biểu] Nguyễn [Ngọc] Hòa , đề nghị : Vấn đề khai thác nước dưới đất cũng được nhiều đại biểu quan tâm , tập trung [góp] ý . Trong Dự thảo quy định việc [thăm] dò khai thác nước [dưới] [đất] với quy mô nhỏ không [cần] phải xin phép [.,] quy định này không được rõ ràng .
#     - multi@3: qut địng → quy định
#     - substitute@18: nguiồn → nguồn
#     - substitute@22: goia → gia
#     - substitute@25: biểiu → biểu
#     - substitute@27: Ngọxc → Ngọc
#     - substitute@50: vóp → góp
#     - substitute@59: tyăm → thăm
#     - multi@64: cdưới đấ5t → dưới đất
#     - substitute@71: cxần → cần
#     - substitute@75: , → ., (punct_only)
#
# —— QA idx=2839 · stratum=random · clean=False · suspect=True · edit_ratio=0.3333
#   SRC: [Fó] Tổng giám đốc Vietnam Airlines [Fan] Xuân Đức [cko] biết : Vietnam Airlines đã báo cáo việc xác [mink] [tkông] tin trên với Cục hàng không Việt Nam .
#   TGT: [Phó] Tổng giám đốc Vietnam Airlines [Phan] Xuân Đức [cho] biết : Vietnam Airlines đã báo cáo việc xác [minh] [thông] tin trên với Cục hàng không Việt Nam .
#     - substitute@0: Fó → Phó
#     - substitute@6: Fan → Phan
#     - substitute@9: cko → cho
#     - multi@19: mink tkông → minh thông
#
# —— QA idx=2962 · stratum=random · clean=False · suspect=False · edit_ratio=0.2
#   SRC: Nguyên [nkân] vụ việc tiếp tục được điều tra .
#   TGT: Nguyên [nhân] vụ việc tiếp tục được điều tra .
#     - substitute@1: nkân → nhân
#
# —— QA idx=2996 · stratum=split · clean=False · suspect=True · edit_ratio=0.3208
#   SRC: [yDân] Việt ) - Hội nghị thượng đỉnh nhóm các nền kinh tế phát triển và [mfi] [lổr] [hscg] đầu [chế] giới ( G20 ) đã khai mạc , với chương trình nghị sự nặng ký là giải [vuyết] khủng hoảng nợ công và bài toán [kgó] mang [xên] Hy Lạp .
#   TGT: [(] [Dân] Việt ) - Hội nghị thượng đỉnh nhóm các nền kinh tế phát triển và [mới] [nổi] [hàng] đầu [thế] giới ( G20 ) đã khai mạc , với chương trình nghị sự nặng ký là giải [quyết] khủng hoảng nợ công và bài toán [khó] mang [tên] Hy Lạp .
#     - split@0: yDân → ( Dân
#     - multi@16: mfi lổr hscg → mới nổi hàng
#     - substitute@20: chế → thế
#     - substitute@38: vuyết → quyết
#     - substitute@46: kgó → khó
#     - substitute@48: xên → tên
#
# —— QA idx=3560 · stratum=suspect · clean=False · suspect=True · edit_ratio=0.3548
#   SRC: Trong một cuộc trả lời phỏng [yấn] tờ Hurriyet của Thổ Nhĩ [Kỳh] Ngoại trưởng Salehi đã nhấn [mạeh] , Iran luôn sẵn sàng cho [mộp] cuộc [chitj] tranh .
#   TGT: Trong một cuộc trả lời phỏng [vấn] tờ Hurriyet của Thổ Nhĩ [Kỳ] [,] Ngoại trưởng Salehi đã nhấn [mạnh] , Iran luôn sẵn sàng cho [một] cuộc [chiến] tranh .
#     - substitute@6: yấn → vấn
#     - split@12: Kỳh → Kỳ ,
#     - substitute@18: mạeh → mạnh
#     - substitute@25: mộp → một
#     - substitute@27: chitj → chiến
#
# —— QA idx=3574 · stratum=insert · clean=False · suspect=False · edit_ratio=0.2292
#   SRC: " Bóng ma " Ghost là mẫu [xes] " bình dân " nhất trong gia [đìnn] Rolls - Royce Ra đời từ năm , Ghost mang trọng trách thu [hbẹp] [khloảng] cách vượt trội giữa Rolls - Royce với các thương hiệu [sxe] sang còn lại .
#   TGT: " Bóng ma " Ghost là mẫu [xe] " bình dân " nhất trong gia [đình] Rolls - Royce Ra đời từ năm [2009] , Ghost mang trọng trách thu [hẹp] [khoảng] cách vượt trội giữa Rolls - Royce với các thương hiệu [xe] sang còn lại .
#     - substitute@7: xes → xe
#     - substitute@15: đìnn → đình
#     - insert@23: ∅ → 2009
#     - multi@29: hbẹp khloảng → hẹp khoảng
#     - substitute@42: sxe → xe
#
# —— QA idx=3788 · stratum=random · clean=False · suspect=True · edit_ratio=0.3158
#   SRC: Tức là [ckàng] trai nào vượt qua được [tkử] [tháck] , đáng mặt tài trai dẫu có [fải] lên rừng xuống biển , với bao khó khăn gian khổ mới được cô gái [ckấp] [nkận] là bạn .
#   TGT: Tức là [chàng] trai nào vượt qua được [thử] [thách] , đáng mặt tài trai dẫu có [phải] lên rừng xuống biển , với bao khó khăn gian khổ mới được cô gái [chấp] [nhận] là bạn .
#     - substitute@2: ckàng → chàng
#     - multi@8: tkử tháck → thử thách
#     - substitute@17: fải → phải
#     - multi@33: ckấp nkận → chấp nhận
#
# —— QA idx=4022 · stratum=substitute · clean=False · suspect=False · edit_ratio=0.2667
#   SRC: Ảnh minh họa ( Nguồn : Camnanggiadinh . com ) Anh [Tiuấn] kể , một lần [cnáu] nghỉ học bán trú buổi sáng , chiều cháu đi học chính quy [bề] , [cjháu] nói [gvới] bố là hôm nay con không [lkàm] được bài .
#   TGT: Ảnh minh họa ( Nguồn : Camnanggiadinh . com ) Anh [Tuấn] kể , một lần [cháu] nghỉ học bán trú buổi sáng , chiều cháu đi học chính quy [về] , [cháu] nói [với] bố là hôm nay con không [làm] được bài .
#     - substitute@11: Tiuấn → Tuấn
#     - substitute@16: cnáu → cháu
#     - substitute@30: bề → về
#     - substitute@32: cjháu → cháu
#     - substitute@34: gvới → với
#     - substitute@41: lkàm → làm
#
# —— QA idx=4058 · stratum=suspect · clean=False · suspect=True · edit_ratio=0.3077
#   SRC: [ò] súng được nối với một sợi dây mảnh giăng ngang [đườnh] .
#   TGT: [Cò] súng được nối với một sợi dây mảnh giăng ngang [đường] .
#     - substitute@0: ò → Cò
#     - substitute@11: đườnh → đường
#
# —— QA idx=4125 · stratum=split · clean=False · suspect=True · edit_ratio=0.3438
#   SRC: Tại [thànhh] phố New York , khoảng [0] cựu [chjiến] binh đã mặc quân phục đi diễu hành , và cuối cùng họ tiến về [t6hị] trường chứng khoán New [Y]
#   TGT: Tại [thành] phố New York , khoảng [100] cựu [chiến] binh đã mặc quân phục đi diễu hành , và cuối cùng họ tiến về [thị] trường chứng khoán New [York] [.]
#     - substitute@1: thànhh → thành
#     - substitute@7: 0 → 100
#     - substitute@9: chjiến → chiến
#     - substitute@25: t6hị → thị
#     - split@30: Y → York .
#
# —— QA idx=4400 · stratum=split · clean=False · suspect=True · edit_ratio=0.3548
#   SRC: Bạn có thể [khôny] [cyhú] ý tới AI khi phòng ngư , [nbưng] theo tôi nó đóng một vai trò [ftối] quan trọng trong PES đặc biệt là PES [0]
#   TGT: Bạn có thể [không] [chú] ý tới AI khi phòng ngư , [nhưng] theo tôi nó đóng một vai trò [tối] quan trọng trong PES đặc biệt là PES [2012] [.]
#     - multi@3: khôny cyhú → không chú
#     - substitute@12: nbưng → nhưng
#     - substitute@20: ftối → tối
#     - split@29: 0 → 2012 .
#
# —— QA idx=4421 · stratum=random · clean=False · suspect=False · edit_ratio=0.1429
#   SRC: Đây là một trong số ít bar mở cửa đến lúc hết [kháck] .
#   TGT: Đây là một trong số ít bar mở cửa đến lúc hết [khách] .
#     - substitute@12: kháck → khách
#
# —— QA idx=4623 · stratum=insert · clean=False · suspect=False · edit_ratio=0.2593
#   SRC: Theo đó , những hộ dân [ị] thu [hồk] đất thuộc phường Tân Mai [đượfc] bố trí tái định cư tại chỗ tại lô đất .
#   TGT: Theo đó , những hộ dân [bị] thu [hồi] đất thuộc phường Tân Mai [được] bố trí tái định cư tại chỗ tại lô đất [HH1] .
#     - substitute@6: ị → bị
#     - substitute@8: hồk → hồi
#     - substitute@14: đượfc → được
#     - insert@25: ∅ → HH1
#
# —— QA idx=4827 · stratum=substitute · clean=False · suspect=True · edit_ratio=0.3077
#   SRC: Như vậy , việc [đăn] ký thành công nhãn hiệu có [trứa] [giấu] hiệu CDĐL cà phê Buôn Ma Thuột nêu [chên] của Công ty TNHH Cà phê Buôn Ma Thuột [Quản] [Trâu] đã [ản] hưởng [chực] tiếp đến quyền lợi nhà sản xuất / kinh doanh sản phẩm cà phê Buôn Ma Thuột khi [trúng] ta xuất khẩu cà phê sang [Chung] Quốc .
#   TGT: Như vậy , việc [đăng] ký thành công nhãn hiệu có [chứa] [dấu] hiệu CDĐL cà phê Buôn Ma Thuột nêu [trên] của Công ty TNHH Cà phê Buôn Ma Thuột [Quảng] [Châu] đã [ảnh] hưởng [trực] tiếp đến quyền lợi nhà sản xuất / kinh doanh sản phẩm cà phê Buôn Ma Thuột khi [chúng] ta xuất khẩu cà phê sang [Trung] Quốc .
#     - substitute@4: đăn → đăng
#     - multi@11: trứa giấu → chứa dấu
#     - substitute@21: chên → trên
#     - multi@31: Quản Trâu → Quảng Châu
#     - substitute@34: ản → ảnh
#     - substitute@36: chực → trực
#     - substitute@55: trúng → chúng
#     - substitute@62: Chung → Trung
#
# —— QA idx=4976 · stratum=random · clean=False · suspect=False · edit_ratio=0.0476
#   SRC: Nhưng chúng có một điểm chung : người ta phản kháng một tầng lớp tinh hoa , thoát ly đại chúng , vốn cảm thấy bị loại ra khỏi sự tăng trưởng kinh tế và [ko] chịu nổi cảnh tham nhũng .
#   TGT: Nhưng chúng có một điểm chung : người ta phản kháng một tầng lớp tinh hoa , thoát ly đại chúng , vốn cảm thấy bị loại ra khỏi sự tăng trưởng kinh tế và [không] chịu nổi cảnh tham nhũng .
#     - substitute@35: ko → không
#
# —— QA idx=4990 · stratum=insert · clean=False · suspect=False · edit_ratio=0.2714
#   SRC: [Thek] phản ánh của người dân , lô đất CT1 [đanmg] được chủ đầu tư rục rịch [chjẩn] bị [zxây] nhà để [nbán] , còn các hộ dân thuộc diện được tái định cư tại CT1 thì UBND quận Hoàng Mai thông báo bố [ttrí] [tạI] 3 nơi : Khu tái định cư Đồng Tầu , Khu đô thị Vĩnh Hoàng và Khu [ô] [5hị] Bắc Linh Đàm .
#   TGT: [Theo] phản ánh của người dân , lô đất CT1 [đang] được chủ đầu tư rục rịch [chuẩn] bị [xây] nhà để [bán] , còn các hộ dân thuộc diện được tái định cư tại CT1 thì UBND quận Hoàng Mai thông báo bố [trí] [tại] 3 nơi [là] : Khu tái định cư Đồng Tầu , Khu đô thị Vĩnh Hoàng và Khu [đô] [thị] Bắc Linh Đàm .
#     - substitute@0: Thek → Theo
#     - substitute@10: đanmg → đang
#     - substitute@17: chjẩn → chuẩn
#     - substitute@19: zxây → xây
#     - substitute@22: nbán → bán
#     - multi@44: ttrí tạI → trí tại
#     - insert@48: ∅ → là
#     - multi@63: ô 5hị → đô thị
#
# —— QA idx=5280 · stratum=clean · clean=True · suspect=False · edit_ratio=0.0
#   SRC: Văn hóa , chính trị Mỹ luôn theo hướng cá nhân chủ nghĩa và ít bình đẳng hơn các nước khác .
#   TGT: Văn hóa , chính trị Mỹ luôn theo hướng cá nhân chủ nghĩa và ít bình đẳng hơn các nước khác .
#
# —— QA idx=5359 · stratum=substitute · clean=False · suspect=False · edit_ratio=0.2162
#   SRC: Trung tâm dữ liệu của Facebook ở Santa Clara đã giảm được 229 . 000 USD [cki] [fí] điện năng / năm bằng việc áp dụng giải [fáp] hoạt động trong môi trường [nkiệt] độ cao .
#   TGT: Trung tâm dữ liệu của Facebook ở Santa Clara đã giảm được 229 . 000 USD [chi] [phí] điện năng / năm bằng việc áp dụng giải [pháp] hoạt động trong môi trường [nhiệt] độ cao .
#     - multi@16: cki fí → chi phí
#     - substitute@27: fáp → pháp
#     - substitute@33: nkiệt → nhiệt
#
# —— QA idx=5438 · stratum=insert · clean=False · suspect=False · edit_ratio=0.2955
#   SRC: Tư thế thay đổi đến [chómg] mặt của ông làm [ư] luận thật sự [boài] nghi rằng điều mà ông gọi là " mệnh lệnh của nhân " [cxó] phải chính là mệnh lệnh đối với [dố] [phậbn] chính trị của ông ?
#   TGT: Tư thế thay đổi đến [chóng] mặt của ông làm [dư] luận thật sự [hoài] nghi rằng điều mà ông gọi là " mệnh lệnh của nhân [dân] " [có] phải chính là mệnh lệnh đối với [số] [phận] chính trị của ông ?
#     - substitute@5: chómg → chóng
#     - substitute@10: ư → dư
#     - substitute@14: boài → hoài
#     - insert@27: ∅ → dân
#     - substitute@28: cxó → có
#     - multi@36: dố phậbn → số phận
#
# —— QA idx=5516 · stratum=punct_only · clean=False · suspect=False · edit_ratio=0.2453
#   SRC: Công khai bán đấu [fiá] đất tái định cư Tại [Q] [địnj] số 81 / 2003 / QĐ - UB ngày 11 - 7 - 2003 , UBND Tp . Hà [Nộui] đã phê duyệt quy hoạch chi [t9ết] hai bên tuyến đường thuộc Dự án đường vành đai 5
#   TGT: Công khai bán đấu [giá] đất tái định cư Tại [Quyết] [định] số 81 / 2003 / QĐ - UB ngày 11 - 7 - 2003 , UBND Tp . Hà [Nội] đã phê duyệt quy hoạch chi [tiết] hai bên tuyến đường thuộc Dự án đường vành đai [2] [.] 5 [.]
#     - substitute@4: fiá → giá
#     - multi@10: Q địnj → Quyết định
#     - substitute@31: Nộui → Nội
#     - substitute@38: t9ết → tiết
#     - insert@49: ∅ → 2 .
#     - insert@50: ∅ → . (punct_only)
#
# —— QA idx=5540 · stratum=punct_only · clean=False · suspect=False · edit_ratio=0.2
#   SRC: Hy Lạp bãi bỏ trưng cầu dân ý Dow Jones vọt [2] điểm .
#   TGT: Hy Lạp bãi bỏ trưng cầu dân ý [,] Dow Jones vọt [280] điểm .
#     - insert@8: ∅ → , (punct_only)
#     - substitute@11: 2 → 280
#
# —— QA idx=5555 · stratum=clean · clean=True · suspect=False · edit_ratio=0.0
#   SRC: Họ công bố cả số điện thoại của nhiều quan chức cảnh sát cao cấp và số thẻ tín dụng của hàng ngàn khách hàng của hãng Sony ...
#   TGT: Họ công bố cả số điện thoại của nhiều quan chức cảnh sát cao cấp và số thẻ tín dụng của hàng ngàn khách hàng của hãng Sony ...
#
# —— QA idx=5697 · stratum=split · clean=False · suspect=False · edit_ratio=0.2281
#   SRC: Legging in hoa Legging in hoa của ASOS : khoảng 1 . 100 . 000 [Đ] Legging hiệu Diane [vion] Furstenburg : khoảng 2 . 625 . 000 VNĐ Legging hiệu Alxander McQueen : khoảng 5 . 565 . 000 [V] Leggings kiểu [een] Legging kiểu [re4n] của Forever [1] khoảng 143 . 000 VNĐ .
#   TGT: Legging in hoa Legging in hoa của ASOS : khoảng 1 . 100 . 000 [VNĐ] Legging hiệu Diane [von] Furstenburg : khoảng 2 . 625 . 000 VNĐ Legging hiệu Alxander McQueen : khoảng 5 . 565 . 000 [VNĐ] Leggings kiểu [ren] Legging kiểu [ren] của Forever [21] [:] khoảng 143 . 000 VNĐ .
#     - substitute@15: Đ → VNĐ
#     - substitute@19: vion → von
#     - substitute@40: V → VNĐ
#     - substitute@43: een → ren
#     - substitute@46: re4n → ren
#     - split@49: 1 → 21 :
#
# —— QA idx=5754 · stratum=substitute · clean=False · suspect=False · edit_ratio=0.25
#   SRC: Đáp lại [tìnk] cảm đó , vào Ngày truyền thống Công an [nkân] dân ( 19 - 8 ), các [link] mục , Ban [hànk] giáo các xứ đều đến [ckúc] mừng , động viên lực lượng công an .
#   TGT: Đáp lại [tình] cảm đó , vào Ngày truyền thống Công an [nhân] dân ( 19 - 8 ), các [linh] mục , Ban [hành] giáo các xứ đều đến [chúc] mừng , động viên lực lượng công an .
#     - substitute@2: tìnk → tình
#     - substitute@12: nkân → nhân
#     - substitute@20: link → linh
#     - substitute@24: hànk → hành
#     - substitute@30: ckúc → chúc
#
# —— QA idx=5813 · stratum=punct_only · clean=False · suspect=False · edit_ratio=0.234
#   SRC: Djokovic đang [gìm] [lạI] cảm giác tốt hơn sau [tyhời] gian [njghỉ] thi [đấui] vì chấn thương Kết quả một số trận [đấy] khác tại vòng 2 Basel Open : Andy Roddick ( 7 ) - Radek Stepanek - 6 - 3 , 6 Stanislas Wawrinka - Robin Haase 4 - 6 , 6 - 1 , 2 Kei Nishikori - Andreas Seppi 6 - 3 , 7 - 6 7 Mikhail Kukushkin - James [Boake] 6 - 3 , 6 - 4 Florian Mayer - Ivan Ljubicic 6 - 3 , 6 - 1 Bất ngờ tại [vòjng] 2 Valencia Open : Hạt giống số 2 Tsonga đã [chuấp] nhận rời cuộc chơi khi [vhịu] thất thủ 0 - 2 trước tay [ợ] người Mỹ , Sam Querrey .
#   TGT: Djokovic đang [tìm] [lại] cảm giác tốt hơn sau [thời] gian [nghỉ] thi [đấu] vì chấn thương Kết quả một số trận [đấu] khác tại vòng 2 Basel Open : Andy Roddick ( 7 ) - Radek Stepanek [2] - [6] [,] 6 - 3 , 6 [-] [3] Stanislas Wawrinka - Robin Haase 4 - 6 , 6 - 1 , [6] [-] 2 Kei Nishikori - Andreas Seppi 6 - 3 , 7 - 6 [(] 7 [-] [4] [)] Mikhail Kukushkin - James [Blake] 6 - 3 , 6 - 4 Florian Mayer - Ivan Ljubicic 6 - 3 , 6 - 1 Bất ngờ tại [vòng] 2 Valencia Open : Hạt giống số 2 Tsonga đã [chấp] nhận rời cuộc chơi khi [chịu] thất thủ 0 - 2 trước tay [vợt] người Mỹ , Sam Querrey .
#     - multi@2: gìm lạI → tìm lại
#     - substitute@9: tyhời → thời
#     - substitute@11: njghỉ → nghỉ
#     - substitute@13: đấui → đấu
#     - substitute@22: đấy → đấu
#     - insert@38: ∅ → 2
#     - insert@39: ∅ → 6 ,
#     - insert@44: ∅ → - 3
#     - insert@57: ∅ → 6 -
#     - insert@70: ∅ → ( (punct_only)
#     - insert@71: ∅ → - 4 )
#     - substitute@75: Boake → Blake
#     - substitute@98: vòjng → vòng
#     - substitute@109: chuấp → chấp
#     - substitute@115: vhịu → chịu
#     - substitute@123: ợ → vợt
#
# Đã in 50 mẫu QA (mục tiêu 50, seed 42) để soát tay.

# %% [markdown]
# ## 8. Xuất file + báo cáo
#
# - `test_aligned.jsonl` — mọi trường của `test_normalized.jsonl` + pseudo-annotation theo **schema giống VSEC** (`error_positions`, `correction_pairs`, `syllable_annotations`, `error_count`, `has_errors` = không clean) + `edit_blocks`, tokens, flags (`is_clean`, `suspect`, `align_failed`, `edit_ratio`) + `shared_cells_version`.
# - `qa_samples.json` — các mẫu QA kèm annotation đầy đủ.
# - `align_report.json` — cấu hình, kết quả kiểm chứng 3 tầng trên gold VSEC, thống kê test, tham chiếu manifest nb0.
#
# **Không xuất** `vsec_*_aligned.jsonl` (quyết định 22/09): nb3 tự tính lại pseudo-annotation cho VSEC-val bằng cell hàm dùng chung — đối chiếu `SHARED_CELLS_VERSION` cho khớp.

# %%
def write_jsonl(path, records):
    with open(path, 'w', encoding='utf-8') as f:
        for r in records:
            f.write(json.dumps(r, ensure_ascii=False) + '\n')


export_records = []
for r in test_aligned:
    a = r['pseudo']
    export_records.append({
        **{k: v for k, v in r.items() if k != 'pseudo'},
        'has_errors': not a['is_clean'],
        'error_count': a['error_count'],
        'error_positions': a['error_positions'],
        'correction_pairs': a['correction_pairs'],
        'syllable_annotations': a['syllable_annotations'],
        'edit_blocks': a['edit_blocks'],
        'is_clean': a['is_clean'],
        'suspect': a['suspect'],
        'align_failed': a['align_failed'],
        'edit_ratio': a['edit_ratio'],
        'src_tokens': a['src_tokens'],
        'tgt_tokens': a['tgt_tokens'],
        'shared_cells_version': SHARED_CELLS_VERSION,
    })

write_jsonl(OUTPUT_DIR / 'test_aligned.jsonl', export_records)

with open(OUTPUT_DIR / 'qa_samples.json', 'w', encoding='utf-8') as f:
    json.dump({'seed': SEED, 'shared_cells_version': SHARED_CELLS_VERSION, 'samples': qa_samples},
              f, ensure_ascii=False, indent=2)

report = {
    'created': RUN_STAMP,
    'notebook': 'nb1_align_annotate',
    'shared_cells_version': SHARED_CELLS_VERSION,
    'config': {'seed': SEED, 'qa_n': QA_N, 'suspect_edit_ratio': SUSPECT_EDIT_RATIO},
    'nb0_manifest_ref': {
        'notebook': manifest_nb0.get('notebook'),
        'created': manifest_nb0.get('created'),
        'vsec_after_dedupe': manifest_vsec_n,
        'test_after_dedupe': manifest_test_n,
    },
    'roundtrip_invariant_ok': True,
    'vsec_gold_validation': {
        'n_sentences': tier['n_sentences'],
        'count_match': tier['count_match'],
        'gold_pairs_total': tier['gold_pairs_total'],
        'gold_pairs_matched': tier['gold_pairs_matched'],
        'blocks_total': tier['blocks_total'],
        'blocks_matched': tier['blocks_matched'],
        'perfect_sentences': tier['perfect_sentences'],
        'pos_eligible_pairs': tier['pos_eligible_pairs'],
        'pos_in_span': tier['pos_in_span'],
        'mismatch_samples_kept': len(mismatch_samples),
    },
    'test': {
        'n': test_sum['n'],
        'clean': test_sum['clean'],
        'clean_strict': test_sum['clean_strict'],
        'suspect': test_sum['suspect'],
        'align_failed': test_sum['align_failed'],
        'only_punct_sentences': test_sum['only_punct_sentences'],
        'punct_only_blocks': test_sum['punct_only_blocks'],
        'block_types': dict(test_sum['block_types']),
        'error_bins': dict(test_sum['error_bins']),
        'vsec_gold_error_bins': dict(vsec_gold_bins),
    },
    'qa': {'n_printed': len(qa_samples), 'strata': dict(STRATA_QUOTAS)},
    'files': ['test_aligned.jsonl', 'qa_samples.json', 'align_report.json'],
}
with open(OUTPUT_DIR / 'align_report.json', 'w', encoding='utf-8') as f:
    json.dump(report, f, ensure_ascii=False, indent=2)

print('Đã ghi vào', OUTPUT_DIR)
print('Files:', report['files'])
print()
print(json.dumps(report, ensure_ascii=False, indent=2))
# Out:
# Đã ghi vào /kaggle/working
# Files: ['test_aligned.jsonl', 'qa_samples.json', 'align_report.json']
#
# {
#   "created": "2026-09-22T08:49:01",
#   "notebook": "nb1_align_annotate",
#   "shared_cells_version": "align-v1",
#   "config": {
#     "seed": 42,
#     "qa_n": 50,
#     "suspect_edit_ratio": 0.3
#   },
#   "nb0_manifest_ref": {
#     "notebook": "nb0_data_prep",
#     "created": "2026-09-22T07:16:53",
#     "vsec_after_dedupe": 9270,
#     "test_after_dedupe": 5983
#   },
#   "roundtrip_invariant_ok": true,
#   "vsec_gold_validation": {
#     "n_sentences": 9270,
#     "count_match": 8970,
#     "gold_pairs_total": 11151,
#     "gold_pairs_matched": 10702,
#     "blocks_total": 10782,
#     "blocks_matched": 10292,
#     "perfect_sentences": 8489,
#     "pos_eligible_pairs": 67,
#     "pos_in_span": 67,
#     "mismatch_samples_kept": 20
#   },
#   "test": {
#     "n": 5983,
#     "clean": 653,
#     "clean_strict": 653,
#     "suspect": 2316,
#     "align_failed": 0,
#     "only_punct_sentences": 0,
#     "punct_only_blocks": 9,
#     "block_types": {
#       "substitute": 18959,
#       "multi": 2729,
#       "split": 176,
#       "insert": 73,
#       "merge": 1
#     },
#     "error_bins": {
#       "0": 653,
#       "1": 672,
#       ">=4": 2792,
#       "3": 914,
#       "2": 952
#     },
#     "vsec_gold_error_bins": {
#       "2": 1210,
#       "1": 7796,
#       "3": 191,
#       ">=4": 73
#     }
#   },
#   "qa": {
#     "n_printed": 50,
#     "strata": {
#       "clean": 10,
#       "substitute": 10,
#       "insert": 5,
#       "delete": 5,
#       "split": 5,
#       "merge": 5,
#       "punct_only": 5,
#       "suspect": 5
#     }
#   },
#   "files": [
#     "test_aligned.jsonl",
#     "qa_samples.json",
#     "align_report.json"
#   ]
# }

# %% [markdown]
# ## 9. Đưa output sang nb2/nb3
#
# 1. Sau khi chạy xong trên Kaggle (*Save Version → Run All*): panel **Output** → chọn `test_aligned.jsonl`, `qa_samples.json`, `align_report.json` → **New Dataset** (ví dụ `vsec-align1`).
# 2. nb2/nb3: **Add Input** → chọn dataset đó (cùng với dataset output nb0).
# 3. nb3 khi copy cell hàm dùng chung phải giữ `SHARED_CELLS_VERSION` nguyên vẹn — nếu buộc phải sửa aligner thì tăng version ở cả 2 nơi và ghi vào nhật ký quyết định của DESIGN.md (nguyên tắc DESIGN.md §7: bị sửa ở ≥2 nơi thì trích `.py` chung).
#
# Bước tiếp theo (DESIGN.md §4): nb2 — bảng âm tiết + non-word rate (Pilot 1), mô hình nhiễu từ `correction_pairs` train + nguồn câu sạch (Pilot 2).
